# %% [markdown]
# # Getting Spotify Data Using an API

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

client = 'f3947a8b5db6403d9ab73c540d61e14c'
secret = '1bb059f762e44ce9af54f075c8c3a8ec'

client_credentials_manager = SpotifyClientCredentials(client_id=client, client_secret=secret)

spotify = spotipy.Spotify(client_credentials_manager = client_credentials_manager)


# name = "{Conan Gray}"

# result = sp.search(name)


conangray = 'spotify:artist:4Uc8Dsxct0oMqx0P6i60ea'


results = spotify.artist_albums(conangray, album_type='album')
albums = results['items']
while results['next']:
    results = spotify.next(results)
    albums.extend(results['items'])

for album in albums:
    print(album['name'])
    
    

tracks = spotify.artist_top_tracks(conangray)

for track in tracks['tracks']:
    print('track:' + track['name'])
    print()
# Out:
# Kid Krow
# Kid Krow
# track:Heather
#
# track:Maniac
#
# track:People Watching
#
# track:Telepath
#
# track:Astronomy
#
# track:Overdrive
#
# track:Fake
#
# track:Lookalike
#
# track:The Story
#
# track:Crush Culture
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-6430c874cf6a> in <module>
#      35     print()
#      36
# ---> 37 audio_features(tracks=[tracks])
#      38
#      39 audio_features()
#
# NameError: name 'audio_features' is not defined

# %% [markdown]
# # Data Visualization using Bokeh & HVPlot

# %%
from bokeh.io import output_notebook

output_notebook() # setup bokeh
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
